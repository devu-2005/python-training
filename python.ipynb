# %% [markdown]
# <a href="https://colab.research.google.com/github/devu-2005/python-training/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input("enter first number:"))
b=int(input("enter second number:"))
print("original value:",a,b)
x=a
y=b
temp=x
x=y
y=temp
print("using temp:",x,y)
x=a
y=b
x,y=y,x
print("using comma",x,y)
x=a
y=b
x=x+y
y=x-y
x=x-y
print("using + and -:",x,y)
x=a
y=b
x=x^y
y=x^y
x=x^y
print("using ^:",x,y)
# Out:
# enter first number:10
# enter second number:20
# original value: 10 20
# using temp: 20 10
# using comma 20 10
# using + and -: 20 10
# using ^: 20 10

# %%
N=10
K=10
n=int(input("enter number of candies:"))
if n>N or n<=0:
  print("INVALID INPUT")
else:
     remaining = N-n
     if remaining < K:
        remainging = N
     print("number of candies sold:",n)
     print("number of candies available:",remaining)
# Out:
# enter number of candies:3
# number of candies sold: 3
# number of candies available: 7

# %%
n=int(input("enter the number of elements:"))
lst=[]
for i in range(n):
  lst.append(input("enter element:"))
print("list:",lst)
# Out:
# enterthe number of elements:4
# enter element:1
# enter element:2
# enter element:3
# enter element:4
# list: ['1', '2', '3', '4']

# %%
n=int(input("enter number of elements:"))
a=[]
for i in range(n):
     a.append(int(input()))
largest=a[0]
for i in range(n):
  if a[i]>largest:
    largest=a[i]
print("largest element:",largest)
# Out:
# enter number of elements:5
# 10
# 25
# 7
# 40
# 15
# largest element: 40

# %%
n=int(input("enter number of elements:"))
a=[]
for i in range(n):
  a.append(int(input()))
smallest=a[0]
for i in range(n):
  if a[i]< smallest:
    smallest=a[i]
print("smallest element:",smallest)
# Out:
# enter number of elements:3
# 2
# 5
# 7
# smallest element: 2

# %%
n=int(input("enter the no of elements:"))
a=[]
for i in range(n):
  a.append(int(input("enter element:")))
sum=0
for i in range(n):
  sum=sum+a[i]
print("sum of the elements:",sum)
# Out:
# enter the no of elements:3
# enter element:1
# enter element:2
# enter element:3
# sum of the elements: 6

# %%
n=int(input("enter the number of elements:"))
a=[]
for i in range(n):
  a.append(int(input("enter element:")))
print("reverse array:")
for i in range(n-1,-1,-1):
  print(a[i])
# Out:
# enter the number of elements:5
# enter element:10
# enter element:20
# enter element:30
# enter element:40
# enter element:50
# reverse array:
# 50
# 40
# 30
# 20
# 10

# %%
n=int(input("enter number of elements:"))
a=[]
for i in range(n):
  a.append(int(input("enter element:")))
x=int(input("enter element to search:"))
if x in a:
  print("element exists")
else:
  print("element does not exist")
# Out:
# enter number of elements:3
# enter element:2
# enter element:4
# enter element:6
# enter element to search:1
# element does not exist

# %%
n=int(input("enter number of elements:"))
a=[]
for i in range(n):
  a.append(int(input("enter element:")))
x=int(input("enter element to count:"))
count=0
for i in range(n):
  if a[i]==x:
    count=count+1
print("number of occurrence:",count)
# Out:
# enter number of elements:5
# enter element:10
# enter element:20
# enter element:30
# enter element:10
# enter element:10
# enter element to count:10
# number of occurrence: 3

# %%
n=int(input("enter number of elements:"))
a=[]
for i in range(n):
  a.append(int(input("enter element:")))
a.sort()
print("second largest element",a[-2])
# Out:
# enter number of elements:5
# enter element:10
# enter element:40
# enter element:20
# enter element:50
# enter element:30
# second largest element 40

# %%
n=int(input("enter the number of element:"))
a=[]
for i in range(n):
  a.append(int(input("enter element:")))
a=list(set(a))
print("after removing duplicates:",a)
# Out:
# enter the number of element:5
# enter element:10
# enter element:20
# enter element:10
# enter element:30
# enter element:10
# after removing duplicates: [10, 20, 30]

# %%
n=int(input("enter the number of elements:"))
a=[]
for i in range(n):
  a.append(int(input("enter element:")))
a.sort()
print("sorted list",a)
# Out:
# enter the number of elements:5
# enter element:2
# enter element:8
# enter element:4
# enter element:7
# enter element:9
# sorted list [2, 4, 7, 8, 9]

# %%
n=int(input("enter the number of elements:"))
a=[]
for i in range(n):
  a.append(int(input("enter element:")))
b=sorted(a)
print("sorted list",b)
# Out:
# enter the number of elements:5
# enter element:6
# enter element:3
# enter element:2
# enter element:7
# enter element:5
# sorted list [2, 3, 5, 6, 7]

# %%
n=int(input("enter number of elements:"))
a=list(map(int,input("enter element:").split()))
print(a)
# Out:
# enter number of elements:3
# enter element:20 10 50
# [20, 10, 50]

# %%
a=[5,10,15,20,25,30]
print(a[:])
print(a[2:])
print(a[:3])
print(a[1:4])
print(a[::-1])
print(a[1:5:2])
# Out:
# [5, 10, 15, 20, 25, 30]
# [15, 20, 25, 30]
# [5, 10, 15]
# [10, 15, 20]
# [30, 25, 20, 15, 10, 5]
# [10, 20]
